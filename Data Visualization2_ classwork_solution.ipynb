# %% [markdown]
# # Class work solution

# %%
# Import dependencies

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %% [markdown]
# 1. No of passangers in each class

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %% [markdown]
# 2. No of passangers in each class that survived

# %%
df1 = df[(df['class']== 'First') & (df['survived']==1)]
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class
# 1           1       1  female  38.0      1      0   71.2833        C  First  \
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
# 889         1       1    male  26.0      0      0   30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.shape
# Out:
# (136, 15)

# %%
df1.shape[0]
# Out:
# 136

# %%
df1 = df[(df['class']== 'Second') & (df['survived']==1)]
df1.shape[0]
# Out:
# 87

# %%
df1 = df[(df['class']== 'Third') & (df['survived']==1)]
df1.shape[0]
# Out:
# 119

# %%
df1 = df[(df['class']== 'First') & (df['survived']==0)]
df2 = df[(df['class']== 'Second') & (df['survived']==0)]
df3 = df[(df['class']== 'Third') & (df['survived']==0)]

df1.shape[0], df2.shape[0], df3.shape[0]
# Out:
# (80, 97, 372)

# %%
df3 = df[(df['sex']== 'female') & (df['embark_town']== 'Southampton') & (df['class']=='Third') & (df['survived']==0)]
df3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 14          0       3  female  14.0      0      0   7.8542        S  Third  \
# 18          0       3  female  31.0      1      0  18.0000        S  Third
# 24          0       3  female   8.0      3      1  21.0750        S  Third
# 38          0       3  female  18.0      2      0  18.0000        S  Third
# 40          0       3  female  40.0      1      0   9.4750        S  Third
# 49          0       3  female  18.0      1      0  17.8000        S  Third
# 71          0       3  female  16.0      5      2  46.9000        S  Third
# 100         0       3  female  28.0      0      0   7.8958        S  Third
# 113         0       3  female  20.0      1      0   9.8250        S  Third
# 119         0       3  female   2.0      4      2  31.2750        S  Third
# 132         0       3  female  47.0      1      0  14.5000        S  Third
# ...

# %%
df3.shape[0]
# Out:
# 55
